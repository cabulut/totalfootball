# %%
#importing packages

import requests
import pandas as pd
from bs4 import BeautifulSoup
import json
import matplotlib.pyplot as plt
import matplotlib as mpl
from mplsoccer.pitch import Pitch, VerticalPitch
from mplsoccer.utils import FontManager

# %%
#scraping

main_url = 'https://understat.com/match/'
match_id = str(input("Insert the match id: "))

url = main_url + match_id
# Out:
# Insert the match id: 16607

# %%
url
# Out:
# 'https://understat.com/match/16607'

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content,'lxml')
scripts = soup.find_all('script')

# %%
#shot data
strings = scripts[1].string

# %%
#strip symbols to have json data

ind_start = strings.index("('")+2
ind_end = strings.index("')")

json_data = strings[ind_start:ind_end]
json_data = json_data.encode('utf8').decode('unicode_escape')

#convert string to json format
data = json.loads(json_data)

# %%
x = []
y = []
xg = []
team = []
result = []

data_away = data['a']
data_home = data['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key =='X':
            x.append(data_home[index][key])
        if key =='Y':
            y.append(data_home[index][key])
        if key =='xG':
            xg.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == "result":
            result.append(data_home[index][key])
            
for index in range(len(data_away)):
    for key in data_away[index]:
        if key =='X':
            x.append(data_away[index][key])
        if key =='Y':
            y.append(data_away[index][key])
        if key =='xG':
            xg.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == "result":
            result.append(data_away[index][key])

# %%
#dataframe

cols = ['x','y','xg','team','result'] # column names
df = pd.DataFrame([x,y,xg,team,result],index=cols) #creating dataframe
df = df.T #transpose the dataframe

# %%
df
# Out:
#                      x                    y                    xg      team  \
# 0   0.8440000152587891                0.475   0.09475582838058472  Brighton
# 1   0.8880000305175781   0.5720000076293945   0.03811180591583252  Brighton
# 2   0.8809999847412109   0.4570000076293945   0.08492165058851242  Brighton
# 3   0.8290000152587891                0.675   0.03191286325454712  Brighton
# 4   0.9269999694824219    0.669000015258789    0.2729357182979584  Brighton
# 5    0.855999984741211   0.5690000152587891   0.07586804777383804  Brighton
# 6    0.919000015258789  0.45299999237060545   0.08224987983703613  Brighton
# 7   0.7680000305175781   0.4909999847412109  0.029895208775997162  Brighton
# 8   0.7930000305175782   0.4209999847412109    0.0369059294462204  Brighton
# 9                 0.86   0.3220000076293945  0.049430087208747864   Chelsea
# 10   0.764000015258789   0.2979999923706055  0.014011413790285587   Chelsea
# 11  0.7930000305175782   0.5329999923706055  0.053450241684913635   Chelsea
# 12  0.8690000152587891  0.35400001525878905   0.08676789700984955   Chelsea
# 13               0.775  0.40700000762939453  0.019627073779702187   Chelsea
# 14  0.8480000305175781   0.7130000305175781  0.027439508587121964   Chelsea
# 15  0.8619999694824219   0.6559999847412109   0.06245436519384384   Chelsea
# 16               0.755    0.534000015258789  0.018253594636917114   Chelsea
# 17               0.785                 0.73  0.014996528625488281   Chelsea
# 18  0.9480000305175781                0.665   0.05822473019361496   Chelsea
# 19   0.879000015258789                 0.56   0.03467565402388573   Chelsea
# 20  0.7319999694824219  0.45799999237060546   0.05194403603672981   Chelsea
# 21                0.88                0.325   0.05526484176516533   Chelsea
# 22   0.769000015258789   0.3920000076293945  0.014290940016508102   Chelsea
# 23               0.765   0.3220000076293945  0.013302917592227459   Chelsea
#
#          result
# 0   MissedShots
# 1   BlockedShot
# 2   BlockedShot
# 3   MissedShots
# 4   MissedShots
# 5     SavedShot
# 6          Goal
# 7   BlockedShot
# 8   BlockedShot
# 9     SavedShot
# 10         Goal
# 11  MissedShots
# 12  MissedShots
# 13  BlockedShot
# 14  BlockedShot
# 15  BlockedShot
# 16  MissedShots
# 17  MissedShots
# 18    SavedShot
# 19  BlockedShot
# 20  BlockedShot
# 21  BlockedShot
# 22  MissedShots
# 23  BlockedShot

# %%
df['x']= (pd.to_numeric(df['x'])/100)*120*100

# %%
df['y']= (pd.to_numeric(df['y'])/100)*80*100

# %%
df['xg'] = pd.to_numeric(df['xg'])

# %%
df
# Out:
#              x          y        xg      team       result
# 0   101.280002  38.000000  0.094756  Brighton  MissedShots
# 1   106.560004  45.760001  0.038112  Brighton  BlockedShot
# 2   105.719998  36.560001  0.084922  Brighton  BlockedShot
# 3    99.480002  54.000000  0.031913  Brighton  MissedShots
# 4   111.239996  53.520001  0.272936  Brighton  MissedShots
# 5   102.719998  45.520001  0.075868  Brighton    SavedShot
# 6   110.280002  36.239999  0.082250  Brighton         Goal
# 7    92.160004  39.279999  0.029895  Brighton  BlockedShot
# 8    95.160004  33.679999  0.036906  Brighton  BlockedShot
# 9   103.200000  25.760001  0.049430   Chelsea    SavedShot
# 10   91.680002  23.839999  0.014011   Chelsea         Goal
# 11   95.160004  42.639999  0.053450   Chelsea  MissedShots
# 12  104.280002  28.320001  0.086768   Chelsea  MissedShots
# 13   93.000000  32.560001  0.019627   Chelsea  BlockedShot
# 14  101.760004  57.040002  0.027440   Chelsea  BlockedShot
# 15  103.439996  52.479999  0.062454   Chelsea  BlockedShot
# 16   90.600000  42.720001  0.018254   Chelsea  MissedShots
# 17   94.200000  58.400000  0.014997   Chelsea  MissedShots
# 18  113.760004  53.200000  0.058225   Chelsea    SavedShot
# 19  105.480002  44.800000  0.034676   Chelsea  BlockedShot
# 20   87.839996  36.639999  0.051944   Chelsea  BlockedShot
# 21  105.600000  26.000000  0.055265   Chelsea  BlockedShot
# 22   92.280002  31.360001  0.014291   Chelsea  MissedShots
# 23   91.800000  25.760001  0.013303   Chelsea  BlockedShot

# %% [markdown]
# ## Visualization

# %%
pitch = VerticalPitch(pad_bottom=0.5,  # pitch extends slightly below halfway line
                      half=True,  # half of a pitch
                      goal_type='box',
                      goal_alpha=0.8)  # control the goal transparency
fig, ax = pitch.draw(figsize=(12, 10))
plt.gca().invert_yaxis()
sc = pitch.scatter(df[df.team=="Chelsea"]["x"],df[df.team=="Chelsea"]["y"],
                   # size varies between 100 and 1000 (points squared)
                   s=(df[df.team=="Chelsea"]["xg"] * 900) + 100,
                   alpha=.8,
                   c='#034694',  # color for scatter in hex format
                   edgecolors='#383838',  # give the markers a charcoal border
                   # for other markers types see: https://matplotlib.org/api/markers_api.html
                   marker='h',
                   ax=ax)

txt = ax.text(x=40, y=80, s='Chelsea Shots vs. Brighton',
              size=30,
              # here i am using a downloaded font from google fonts instead of passing a fontdict
              color=pitch.line_color,
              va='center', ha='center')

# %%
df[df.team=="Chelsea"]
# Out:
#              x          y                    xg     team       result
# 9   103.200000  38.640001  0.049430087208747864  Chelsea    SavedShot
# 10   91.680002  35.759999  0.014011413790285587  Chelsea         Goal
# 11   95.160004  63.959999  0.053450241684913635  Chelsea  MissedShots
# 12  104.280002  42.480002   0.08676789700984955  Chelsea  MissedShots
# 13   93.000000  48.840001  0.019627073779702187  Chelsea  BlockedShot
# 14  101.760004  85.560004  0.027439508587121964  Chelsea  BlockedShot
# 15  103.439996  78.719998   0.06245436519384384  Chelsea  BlockedShot
# 16   90.600000  64.080002  0.018253594636917114  Chelsea  MissedShots
# 17   94.200000  87.600000  0.014996528625488281  Chelsea  MissedShots
# 18  113.760004  79.800000   0.05822473019361496  Chelsea    SavedShot
# 19  105.480002  67.200000   0.03467565402388573  Chelsea  BlockedShot
# 20   87.839996  54.959999   0.05194403603672981  Chelsea  BlockedShot
# 21  105.600000  39.000000   0.05526484176516533  Chelsea  BlockedShot
# 22   92.280002  47.040001  0.014290940016508102  Chelsea  MissedShots
# 23   91.800000  38.640001  0.013302917592227459  Chelsea  BlockedShot

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xl/hkbhm9vn4cj3ffm06jxp57c40000gn/T/ipykernel_26562/1028141915.py in <module>
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
(df[df.team=="Chelsea"]["xg"] * 900) + 100
# Out:
# 9     144.487078
# 10    112.610272
# 11    148.105218
# 12    178.091107
# 13    117.664366
# 14    124.695558
# 15    156.208929
# 16    116.428235
# 17    113.496876
# 18    152.402257
# 19    131.208089
# 20    146.749632
# 21    149.738358
# 22    112.861846
# 23    111.972626
# Name: xg, dtype: float64
